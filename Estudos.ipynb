# %% [markdown]
# <a href="https://colab.research.google.com/github/ericlesvieira/estudos/blob/master/Estudos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(ggplot2)
library(tidyverse)
library(patchwork)

# %% [markdown]
# **R for Data Science**

# %% [markdown]
# **3.5 facets**  **Exercises**
# 1. What happens if you facet on a continuous variable?
#
# **R= maked one facet  to each one value in the variable!**

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(~hwy )
# Out:
# plot without title

# %% [markdown]
# 2. What do the empty cells in plot with facet_grid(drv ~ cyl) mean? How do they relate to this plot?
# **R=The empty cell is a empty value in the cyl and drv variable.**

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = drv, y = cyl))+
  facet_grid(drv ~ cyl)

  ggplot(data = mpg) + 
  geom_point(mapping = aes(x = drv, y = cyl))
# Out:
# plot without title
# plot without title

# %% [markdown]
# 3. What plots does the following code make? What does . do?
# **R= The plots make a facets in diferent orientations. The . represet the all other data.**

# %%
ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(.~drv )


  ggplot(data = mpg) + 
  geom_point(mapping = aes(x = displ, y = hwy)) +
  facet_grid(drv~.)
# Out:
# plot without title
# plot without title

# %% [markdown]
# 4. Take the first faceted plot in this section:
#
# ggplot(data = mpg) +
#   geom_point(mapping = aes(x = displ, y = hwy)) +
#   facet_wrap(~ class, nrow = 2)
#
#   R=

# %%
mpg %>%
filter(class == '2seater') %>%
  ggplot() + 
  geom_point(mapping = aes(x = displ, y = hwy)) + 
  facet_wrap(~ class, nrow = 2)
# Out:
# plot without title

# %% [markdown]
# 4. What are the advantages to using faceting instead of the colour aesthetic? What are the disadvantages? How might the balance change if you had a larger dataset?
#
# **R = In facets show a clean visualize but in lager datasets with morer variables is a not better option in contrast to colour aesthetic.**

# %% [markdown]
# 5. Read ?facet_wrap. What does nrow do? What does ncol do? What other options control the layout of the individual panels? Why doesn’t facet_grid() have nrow and ncol arguments?
#
# **R=  nrow change the number of row of the panels and ncol number of cols.
# dir change the direction of the panels. The facet_grid haven't the argument because facetgrid plot te row and/or cols in two ordered variabels, the option row and cols can be used to select rows and cols in the data to plot.**
#
#
# 6. When using facet_grid() you should usually put the variable with more unique levels in the columns. Why?
#
# **R= Because the size of the plots have better in this configurations.**

# %% [markdown]
# **3.6 Geometric objects**
# 3.6.1 Exercises
#
# 1. What geom would you use to draw a line chart? A boxplot? A histogram? An area chart?
#
# **R= geom_boxplot; geom_line; geom_histogram; geom_area**
#
# 2. Run this code in your head and predict what the output will look like. Then, run the code in R and check your predictions.
#
# ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = drv)) +
#   geom_point() +
#   geom_smooth(se = FALSE)
#
#   **R =  The se in geom_smooth hide the confidential interval around the smooth.**
#
#   3. What does show.legend = FALSE do? What happens if you remove it?
# Why do you think I used it earlier in the chapter?
#
# **R= Hide the legend. You don't used because the arrange of the plot.**
#
# 4. What does the se argument to geom_smooth() do?
#
#  **R =  The se in geom_smooth hide the confidential interval around the smooth.**
#  5.Will these two graphs look different? Why/why not?
#
# ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
#   geom_point() +
#   geom_smooth()
#
# ggplot() +
#   geom_point(data = mpg, mapping = aes(x = displ, y = hwy)) +
#   geom_smooth(data = mpg, mapping = aes(x = displ, y = hwy))
#
#   **R= Two graphs is identical in the print.**
#
#   6. Recreate the R code necessary to generate the following graphs.

# %%
#plot1
mpg%>%
ggplot(aes(x=displ,y=hwy))+
geom_point()+
geom_smooth(se=F)
#plot2
mpg%>%
ggplot(aes(x=displ,y=hwy))+
geom_point()+
geom_smooth(se=F, aes(group=drv ))
#plot3
mpg%>%
ggplot(aes(x=displ,y=hwy, color=drv))+
geom_point()+
geom_smooth(se=F)
#plot4
mpg%>%
ggplot(aes(x=displ,y=hwy))+
geom_point(aes(color=drv))+
geom_smooth(se=F)
#plot5
mpg%>%
ggplot(aes(x=displ,y=hwy))+
geom_point(aes(color=drv))+
geom_smooth(se=F, aes(linetype = drv))
#plot6
mpg%>%
ggplot(aes(x=displ,y=hwy)) +
geom_point(aes(fill = drv), color = 'white', shape = 21, size = 10)
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
#
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title
# plot without title
# plot without title
